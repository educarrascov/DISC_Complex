# %%
pip install cellpylib
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for cellpylib: filename=cellpylib-2.4.0-py3-none-any.whl size=37929 sha256=24162a9ef64a03b78af65f8180235c780768c32402b84f50720ad8e7fcf08469
#   Stored in directory: /Users/educarrascovidal/Library/Caches/pip/wheels/8d/99/7b/e22e3050aac196673184a559b605f04c264f8b672f1c028208
# Successfully built cellpylib
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cellpylib as cpl

cellular_automaton = cpl.init_simple(500)

cellular_automaton = cpl.evolve(cellular_automaton, timesteps=300, memoize=True,
                                apply_rule=lambda n, c, t: cpl.nks_rule(n, 30))

# %%
cpl.plot(cellular_automaton)
